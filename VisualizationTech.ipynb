# %% [markdown]
# <a href="https://colab.research.google.com/github/Mileye22/Mileye22/blob/main/VisualizationTech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mo = pd.read_csv('/content/monthly_test.csv')

# %%
mo
# Out:
#         Month    Year  Revenue     Cost   Profit
# 0       April  2014.0  46553.0  19360.0  27193.0
# 1       April  2016.0  44463.0  18573.0  25890.0
# 2      August  2013.0  47834.0  19750.0  28084.0
# 3      August  2015.0  45325.0  18638.0  26687.0
# 4    December  2013.0  59880.0  25572.0  34308.0
# 5    December  2015.0  57646.0  24598.0  33048.0
# 6    February  2014.0  40342.0  16978.0  23364.0
# 7    February  2016.0  38264.0  16179.0  22085.0
# 8     January  2014.0  43888.0  17994.0  25894.0
# 9     January  2016.0  41238.0  16872.0  24366.0
# 10       July  2013.0  17786.0   7452.0  10334.0
# 11       July  2014.0  28423.0  11772.0  16651.0
# 12       July  2015.0  15942.0   6710.0   9232.0
# 13       July  2016.0  26528.0  11000.0  15528.0
# 14       June  2014.0  63778.0  26207.0  37571.0
# 15       June  2016.0  60958.0  25040.0  35918.0
# 16      March  2014.0  43727.0  18687.0  25040.0
# 17      March  2016.0  41422.0  17685.0  23737.0
# ...

# %%
mo.loc[20:23]
# Out:
#        Month    Year  Revenue     Cost   Profit
# 20  November  2013.0  54215.0  22596.0  31619.0
# 21  November  2015.0  52772.0  21926.0  30846.0
# 22   October  2013.0  47569.0  19617.0  27952.0
# 23   October  2015.0  46052.0  18963.0  27089.0

# %%
mo.at[23, 'Revenue']
# Out:
# 46052.0

# %%
mo.Revenue
# Out:
# 0     46553.0
# 1     44463.0
# 2     47834.0
# 3     45325.0
# 4     59880.0
# 5     57646.0
# 6     40342.0
# 7     38264.0
# 8     43888.0
# 9     41238.0
# 10    17786.0
# 11    28423.0
# 12    15942.0
# 13    26528.0
# 14    63778.0
# 15    60958.0
# 16    43727.0
# 17    41422.0
# 18    67466.0
# 19    63446.0
# 20    54215.0
# 21    52772.0
# 22    47569.0
# 23    46052.0
# 24    50590.0
# 25    46996.0
# Name: Revenue, dtype: float64

# %%
Tot = mo[['Revenue', 'Cost']].sum()

# %%
Tot_n = mo['Revenue'].sum()

# %%
Tot_n
# Out:
# 1193103.0

# %%
print(f"The total revenue is ${Tot_n:,.2f}")
# Out:
# The total revenue is $1,193,103.00

# %%
mo.sort_values(['Revenue', 'Cost'], inplace = True)

# %%
mo
# Out:
#         Month    Year  Revenue     Cost   Profit
# 12       July  2015.0  15942.0   6710.0   9232.0
# 10       July  2013.0  17786.0   7452.0  10334.0
# 13       July  2016.0  26528.0  11000.0  15528.0
# 11       July  2014.0  28423.0  11772.0  16651.0
# 7    February  2016.0  38264.0  16179.0  22085.0
# 6    February  2014.0  40342.0  16978.0  23364.0
# 9     January  2016.0  41238.0  16872.0  24366.0
# 17      March  2016.0  41422.0  17685.0  23737.0
# 16      March  2014.0  43727.0  18687.0  25040.0
# 8     January  2014.0  43888.0  17994.0  25894.0
# 1       April  2016.0  44463.0  18573.0  25890.0
# 3      August  2015.0  45325.0  18638.0  26687.0
# 23    October  2015.0  46052.0  18963.0  27089.0
# 0       April  2014.0  46553.0  19360.0  27193.0
# 25  September  2015.0  46996.0  19694.0  27302.0
# 22    October  2013.0  47569.0  19617.0  27952.0
# 2      August  2013.0  47834.0  19750.0  28084.0
# 24  September  2013.0  50590.0  21099.0  29491.0
# ...

# %%
mo1 = mo.pivot('Month','Year', 'Revenue')
mo1
# Out:
# Year        2013.0   2014.0   2015.0   2016.0
# Month
# April          NaN  46553.0      NaN  44463.0
# August     47834.0      NaN  45325.0      NaN
# December   59880.0      NaN  57646.0      NaN
# February       NaN  40342.0      NaN  38264.0
# January        NaN  43888.0      NaN  41238.0
# July       17786.0  28423.0  15942.0  26528.0
# June           NaN  63778.0      NaN  60958.0
# March          NaN  43727.0      NaN  41422.0
# May            NaN  67466.0      NaN  63446.0
# November   54215.0      NaN  52772.0      NaN
# October    47569.0      NaN  46052.0      NaN
# September  50590.0      NaN  46996.0      NaN

# %%
mo2 = mo.pivot('Month', 'Year', 'Cost')

# %%
mo2
# Out:
# Year        2013.0   2014.0   2015.0   2016.0
# Month
# April          NaN  19360.0      NaN  18573.0
# August     19750.0      NaN  18638.0      NaN
# December   25572.0      NaN  24598.0      NaN
# February       NaN  16978.0      NaN  16179.0
# January        NaN  17994.0      NaN  16872.0
# July        7452.0  11772.0   6710.0  11000.0
# June           NaN  26207.0      NaN  25040.0
# March          NaN  18687.0      NaN  17685.0
# May            NaN  27493.0      NaN  25762.0
# November   22596.0      NaN  21926.0      NaN
# October    19617.0      NaN  18963.0      NaN
# September  21099.0      NaN  19694.0      NaN

# %%
mo1.fillna(0, inplace = True)

# %%
mo2.fillna(0, inplace = True)

# %%
mo1
# Out:
# Year        2013.0   2014.0   2015.0   2016.0
# Month
# April          0.0  46553.0      0.0  44463.0
# August     47834.0      0.0  45325.0      0.0
# December   59880.0      0.0  57646.0      0.0
# February       0.0  40342.0      0.0  38264.0
# January        0.0  43888.0      0.0  41238.0
# July       17786.0  28423.0  15942.0  26528.0
# June           0.0  63778.0      0.0  60958.0
# March          0.0  43727.0      0.0  41422.0
# May            0.0  67466.0      0.0  63446.0
# November   54215.0      0.0  52772.0      0.0
# October    47569.0      0.0  46052.0      0.0
# September  50590.0      0.0  46996.0      0.0

# %%
hm = sns.heatmap(mo2, cmap = 'crest', annot = True, fmt = ',.2f')
hm.set(xlabel = '', ylabel = '')
hm.xaxis.tick_top()
plt.title('Title heatmap2');

# %%
hm = sns.heatmap(mo1, cmap = 'crest', annot = True, fmt = '.2f')
hm.set(xlabel = '', ylabel = '')
hm.xaxis.tick_top()
plt.title('Title heatmap');

# %%
fig, axs = plt.subplots(2,2)

;
# Out:
# ''

# %%
plt.plot(mo.Revenue);

# %%
plt.plot(mo.Year, mo.Revenue)

# %%
plt.plot(mo.Year, mo.Revenue, 'sb')

# %%
sns.scatterplot(mo.Year, mo.Revenue)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
app_yields = [ 1.2, 2.5, 2.4, 0.8, 1.5 ]
app_yields
# Out:
# [1.2, 2.5, 2.4, 0.8, 1.5]

# %%
years = list(np.arange(2015,2025,2))
years
# Out:
# [2015, 2017, 2019, 2021, 2023]

# %%
plt.plot(app_yields)

# %%
plt.plot(years, app_yields)

# %%
plt.ylabel('Year')

plt.xlabel('yields')

plt.plot( app_yields, years)

# %%
ban_yields = [7.5, 4.8, 3.5, 5.8, 6]

# %%
plt.plot(years, ban_yields)
plt.plot(years, app_yields)

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')
# Out:
# Text(0, 0.5, 'Yield (tonnes)')

# %%
plt.plot(years, ban_yields)
plt.plot(years, app_yields)

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.plot(years, ban_yields, marker = 'o')
plt.plot(years, app_yields, marker = 'x')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--', lw = 2, ms = 4, mew = 2)
plt.plot(years, app_yields, marker = 'x', c = 'r', alpha = .6)

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.plot(years, ban_yields, 's-y')
plt.plot(years, app_yields, 'x--r')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--', lw = 2, ms = 4, mew = 2)
plt.plot(years, app_yields, 'xr')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.figure(figsize=(12,5))

plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--')
plt.plot(years, app_yields, 'xr')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(12,5))

plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--')
plt.plot(years, app_yields, 'xr')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--')
plt.plot(years, app_yields, 'xr')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.figure(figsize=(12,5))

plt.plot(years, ban_yields, marker = 'o', c = 'y', ls =  '--')
plt.plot(years, app_yields, 'xr')

plt.xlabel('Year')
plt.ylabel('Yield (tonnes)')

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County');

# %%
plt.figure(figsize=(12,5))

# %%
plt.plot(app_yields)

# %%
import matplotlib

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12,5)
matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
plt.plot(app_yields)

# %%
nw = sns.load_dataset('iris')

# %%
nw
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(nw.sepal_length, nw.sepal_width)

# %%
plt.plot(nw.sepal_length, nw.sepal_width, 'ob')

# %%
nw.columns.unique()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
nw.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(nw.sepal_length, nw.sepal_width)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(nw.sepal_length, nw.sepal_width, hue = nw.species, s = 80);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (12,6))
plt.title('Sepal Dimensions')
sns.scatterplot(nw.sepal_length, nw.sepal_width, hue = nw.species, s = 80);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(nw.petal_length, nw.petal_width, hue = nw.species, s=80)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (12,6))
plt.title('Petal Dimensions')
sns.scatterplot(nw.petal_length, nw.petal_width, hue = nw.species, s=80)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
nw.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
nw.sepal_width.describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)>

# %%
plt.title('Distribution of Sepal_width')
plt.hist(nw.sepal_width, color= 'r')
  #plt.hist(nw.sepal_length)
  #plt.hist(nw.petal_width)
  #plt.hist(nw.petal_length)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(nw.sepal_width, bins = 5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(nw.sepal_width, bins = np.arange(2,5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <a list of 11 Patch objects>)

# %%
seto = nw[nw.species == 'setosa']
versi = nw[nw.species == 'versicolor']
virgi = nw[nw.species == 'virginica']

# %%
plt.hist(seto.sepal_width, bins = np.arange(2,5,0.25), alpha = .4)
plt.hist(versi.sepal_width, bins = np.arange(2,5,0.25), alpha = .4)
plt.hist(virgi.sepal_width,  bins = np.arange(2,5,0.25),  alpha= .4)

plt.legend(['setosa','versicolor', 'virginica'])

# %%
plt.hist([seto.sepal_width, versi.sepal_width, virgi.sepal_width], alpha = 0.4, bins = np.arange(2,5,0.25), stacked = True)

plt.legend(['setosa','versicolor', 'virginica'])

# %%
plt.hist([seto.sepal_width, versi.sepal_width, virgi.sepal_width], bins = np.arange(2,5,0.25), stacked = True)
plt.legend(['setosa','versicolor', 'virginica'])

# %%
years2 = np.arange(2000,2005)
app_yields
ban_yields
# Out:
# [7.5, 4.8, 3.5, 5.8, 6]

# %%
ban_yields[2] = 2
ban_yields
# Out:
# [7.5, 4.8, 2, 5.8, 6]

# %%
years2 = np.arange(2000,2005)
app_yields
# Out:
# [1.2, 2.5, 2.4, 0.8, 1.5]

# %%
years2
# Out:
# array([2000, 2001, 2002, 2003, 2004])

# %%
years2_ax = np.arange(len(years2))

plt.bar(years2_ax - 0.2, ban_yields ,0.4)
plt.bar(years2_ax + 0.2,  app_yields ,0.4)

plt.xticks(years2_ax, years)
plt.legend(['Bananas', 'Apples'])


plt.title('Crop yields in My County')
# Out:
# Text(0.5, 1.0, 'Crop yields in My County')

# %%
plt.bar(years2, ban_yields)
plt.bar(years2,  app_yields, bottom = ban_yields)

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County')
# Out:
# Text(0.5, 1.0, 'Crop yields in My County')

# %%
plt.bar(years2, ban_yields, bottom = app_yields)
plt.bar(years2,  app_yields)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(years2 - 0.2, ban_yields, 0.4, alpha = .7)
plt.bar(years2 + 0.2,  app_yields, 0.4, alpha = .5)

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County')
# Out:
# Text(0.5, 1.0, 'Crop yields in My County')

# %%
plt.bar(years2, ban_yields, 0.5)
plt.bar(years2,  app_yields, 0.4)
plt.plot(years2, ban_yields)
plt.plot(years2,  app_yields)

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.bar(years2 - 0.2, ban_yields, 0.4)
plt.bar(years2 + 0.2,  app_yields, 0.4)

plt.legend(['Bananas', 'Apples'])
plt.title('Crop yields in My County')
# Out:
# Text(0.5, 1.0, 'Crop yields in My County')

# %%
oth = sns.load_dataset('tips')

# %%
oth
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
avg_bill = oth.groupby('day')[['total_bill']].mean()

# %%
avg_bill
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar
# Out:
# <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# %%
plt.bar(avg_bill.index, avg_bill.total_bill, width = 0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize = (4,2))

# %%
plt.figure(figsize = (8,6))
navg_bill = sns.barplot('day', 'total_bill', data = oth)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot
# Out:
# <function seaborn.categorical.barplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x7f66e9082b00>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)>

# %%
plt.figure(figsize = (8,6))
navg_bill = sns.barplot('day', 'total_bill', data = oth, hue = 'sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (8,6))
navg_bill = sns.barplot('day', 'total_bill', data = oth, hue= 'smoker')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (8,6))
navg_bill = sns.barplot('total_bill', 'day',  data = oth, hue = 'sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ### Heatmaps

# %%
flght = sns.load_dataset('flights')

# %%
flght
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flght.passengers.plot()

# %%
plt.plot(flght.passengers)

# %%
flt = flght.pivot('month', 'year', 'passengers')
flt
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("Heat map of passengers")
sns.heatmap(flt)

# %%
plt.title("Heat map of passengers")
sns.heatmap(flt, fmt = 'd', annot = True , cmap = 'Blues')

# %%
plt.title("Heat map of passengers")
sns.heatmap(flt, fmt = 'd', annot = True )

# %% [markdown]
# ### Images

# %% [markdown]
# # Plotting Multiple Charts

# %%
fig, axes = plt.subplots(2,3, figsize= (16,6))
plt.tight_layout(pad = 4)

axes[0,0].plot(years, app_yields, 's-b')
axes[0,0].set_xlabel('Years')
axes[0,0].set_ylabel('Yields')
axes[0,0].set_title('Crop yields')

axes[0,1].set_title('Sepal_lenght vs width')
sns.scatterplot(nw.sepal_length, nw.sepal_width, hue = nw.species, s =80, ax =axes[0,1]);

axes[1,0].set_title('Histogram of  Sepal_length')
sns.histplot(nw.sepal_length, ax = axes[1,0])

axes[1,1].set_title('Bar plot of Crop yields')
sns.barplot(years, app_yields, ax= axes[1,1]);

axes[0,2].set_title('Heat map plot')
sns.heatmap(flt, fmt = 'd', annot = True , cmap = 'Blues', ax =axes[0,2])

axes[1,2].set_title('Last plot')
navg_bill = sns.barplot('day', 'total_bill', data = oth, hue= 'smoker', ax = axes[1,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://images.pexels.com/photos/235621/pexels-photo-235621.jpeg', 'im.jpeg');
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-108-6436d6dae509> in <module>
# ----> 1 urlretrieve('https://images.pexels.com/photos/235621/pexels-photo-235621.jpeg', 'im.jpeg');
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
urlretrieve('https://www.kaggle.com/datasets/uciml/iris/download', 'or.csv')

https://www.kaggle.com/datasets/uciml/iris/download?datasetVersionNumber=2

# %%
urlretrieve('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', 's.csv')

# %%
s =pd.read_csv('/content/s.csv', on_bad_lines='skip')

# %%
s

# %%
s.set_columns([['length'], ['breadth'],['gii'],['ftu']])

# %%
pd.read_csv('/content/or.csv', on_bad_lines='skip')

# %%
import requests

# %%
we = requests.get('https://www.kaggle.com/datasets/uciml/iris/download?datasetVersionNumber=2')

# %%
we.headers['Content-type']

# %%
pd.read_csv('/content/iris.csv')

# %%
http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
pla = pd.read_csv('https://raw.githubusercontent.com/datagy/data/main/sales.csv', parse_dates=['date'])
print(df.head())
